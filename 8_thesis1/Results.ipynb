# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pDist_H1_05_Med50 = np.loadtxt("pDist_H1_05_Med50.csv", dtype = float, delimiter = ",")
pDist_H1_05_Med100 = np.loadtxt("pDist_H1_05_Med.csv", dtype = float, delimiter = ",")
pDist_H1_05_Med150 = np.loadtxt("pDist_H1_05_Med150.csv", dtype = float, delimiter = ",")

# %%
pDist_H0_05_Med50 = np.loadtxt("pDist_H0_05_Med50.csv", dtype = float, delimiter = ",")
pDist_H0_05_Med100 = np.loadtxt("pDist_H0_05_Med.csv", dtype = float, delimiter = ",")
pDist_H0_05_Med150 = np.loadtxt("pDist_H0_05_Med150.csv", dtype = float, delimiter = ",")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/rw119/git/M4Rproject/8_thesis1/Results.ipynb Cell 3 in 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bnvidia4.ma.ic.ac.uk/home/rw119/git/M4Rproject/8_thesis1/Results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> pDist_H0_05_Med50 = np.loadtxt("pDist_H0_05_Med50.csv", dtype = float, delimiter = ",")
#       <a href='vscode-notebook-cell://ssh-remote%2Bnvidia4.ma.ic.ac.uk/home/rw119/git/M4Rproject/8_thesis1/Results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> pDist_H0_05_Med100 = np.loadtxt("pDist_H0_05_Med.csv", dtype = float, delimiter = ",")
#       <a href='vscode-notebook-cell://ssh-remote%2Bnvidia4.ma.ic.ac.uk/home/rw119/git/M4Rproject/8_thesis1/Results.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> pDist_H0_05_Med150 = np.loadtxt("pDist_H0_05_Med150.csv", dtype = float, delimiter = ",")
#
# ...

# %%
fig = plt.figure(figsize =(16, 4))
# fig.suptitle("H1, samplesize=100, bandwidth=1, mean=0.5all", fontsize = 16)

ax = fig.add_subplot(131)
ax.boxplot(pDist_H1_05_Med50.T)
ax.set_xticklabels([1, 10, 50, 100, 500, 1000, 1500])
ax.axhline(0.1)
ax.set_xlabel("dimension")
ax.set_ylabel("p value")

ax1 = fig.add_subplot(132)
ax1.boxplot(pDist_H1_05_Med100.T)
ax1.set_xticklabels([1, 10, 50, 100, 500, 1000, 1500])
ax1.axhline(0.1)
ax1.set_xlabel("dimension")
ax1.set_ylabel("p value")

ax2 = fig.add_subplot(133)
ax2.boxplot(pDist_H1_05_Med150.T)
ax2.set_xticklabels([1, 10, 50, 100, 500, 1000, 1500])
ax2.axhline(0.1)
ax2.set_xlabel("dimension")
ax2.set_ylabel("p value")

plt.show()

# %%
pDist_nvsmean_042 = np.loadtxt("pDist_nvsmean_042.csv", dtype = float, delimiter = ",")
pDist_nvsmean_045 = np.loadtxt("pDist_nvsmean_045.csv", dtype = float, delimiter = ",")
pDist_nvsmean_050 = np.loadtxt("pDist_nvsmean_050.csv", dtype = float, delimiter = ",")

pDist_nvsmean = np.array([pDist_nvsmean_042, pDist_nvsmean_045, pDist_nvsmean_050])

# %%
fig = plt.figure(figsize =(16, 4))
# fig.suptitle("H1, samplesize=100, bandwidth=1, mean=0.5all", fontsize = 16)

ax = fig.add_subplot(121)
ax.boxplot(pDist_nvsmean.T)
ax.set_xticklabels(['0.42', '0.45', '0.50'])
ax.axhline(0.1)
ax.set_ylim(0, 1)
ax.set_xlabel("mean shift")
ax.set_ylabel("p value")


ax1 = fig.add_subplot(122)
ax1.boxplot(pDist_nvsmean_045)
ax1.axhline(0.1)
ax1.set_ylim(0, 1)
ax1.set_xlabel("dimension")
ax1.set_ylabel("p value")

plt.show()

# %%
pDist_H1_Med05R = np.loadtxt("pDist_H1_Med05R.csv", dtype = float, delimiter = ",")
pDist_H1_Med04R = np.loadtxt("pDist_H1_Med04R.csv", dtype = float, delimiter = ",")
pDist_H1_Med03R = np.loadtxt("pDist_H1_Med03R.csv", dtype = float, delimiter = ",")

# %%
fig = plt.figure(figsize =(15, 3))
# fig.suptitle("H1, samplesize=100, bandwidth=1, mean=0.5", fontsize = 16)

ax5 = fig.add_subplot(131)
ax5.boxplot(pDist_H1_Med05R.T)
ax5.set_xticklabels([5, 10, 50, 100, 150, 200, 300])
ax5.axhline(0.1)
ax5.set_xlabel("dimension")
ax5.set_ylabel("p value")

ax4 = fig.add_subplot(132)
ax4.boxplot(pDist_H1_Med04R.T)
ax4.set_xticklabels([5, 10, 50, 100, 150, 200, 300])
ax4.axhline(0.1)
ax4.set_xlabel("dimension")
ax4.set_ylabel("p value")

ax3 = fig.add_subplot(133)
ax3.boxplot(pDist_H1_Med03R.T)
ax3.set_xticklabels([5, 10, 50, 100, 150, 200, 300])
ax3.axhline(0.1)
ax3.set_xlabel("dimension")
ax3.set_ylabel("p value")

plt.show()

# %%
pDist_H1_Med42R = np.loadtxt("pDist_H1_Med42R.csv", dtype = float, delimiter = ",")
pDist_H1_Med45R = np.loadtxt("pDist_H1_Med45R.csv", dtype = float, delimiter = ",")
pDist_H1_Med47R = np.loadtxt("pDist_H1_Med47R.csv", dtype = float, delimiter = ",")

# %%
fig = plt.figure(figsize =(15, 3))
# fig.suptitle("H1, samplesize=100, bandwidth=1, mean=0.5", fontsize = 16)

ax5 = fig.add_subplot(131)
ax5.boxplot(pDist_H1_Med42R.T)
ax5.set_xticklabels([5, 10, 50, 100, 150, 200, 300])
ax5.axhline(0.1)
ax5.set_xlabel("dimension")
ax5.set_ylabel("p value")

ax4 = fig.add_subplot(132)
ax4.boxplot(pDist_H1_Med45R.T)
ax4.set_xticklabels([5, 10, 50, 100, 150, 200, 300])
ax4.axhline(0.1)
ax4.set_xlabel("dimension")
ax4.set_ylabel("p value")

ax3 = fig.add_subplot(133)
ax3.boxplot(pDist_H1_Med47R.T)
ax3.set_xticklabels([5, 10, 50, 100, 150, 200, 300])
ax3.axhline(0.1)
ax3.set_xlabel("dimension")
ax3.set_ylabel("p value")

plt.show()

# %%
pDist_H1_04_Med200 = np.loadtxt("pDist_H1_05_Med500.csv", dtype = float, delimiter = ",")
pDist_H1_05_Med = np.loadtxt("pDist_H1_05_Med.csv", dtype = float, delimiter = ",")

# %%
pDist_H1_04_Med200 = np.loadtxt("pDist_H1_05_Med500.csv", dtype = float, delimiter = ",")
pDist_H1_05_Med = np.loadtxt("pDist_H1_05_Med.csv", dtype = float, delimiter = ",")

# %%
fig = plt.figure(figsize =(13, 5))
# fig.suptitle("H1, samplesize=100, bandwidth=1, mean=0.5all", fontsize = 16)

ax = fig.add_subplot(121)
ax.boxplot(pDist_H1_04_Med200.T)
ax.set_xticklabels([5, 10, 50, 100, 150, 200, 300])
ax.axhline(0.1)
ax.set_xlabel("dimension")
ax.set_ylabel("p value")

ax1 = fig.add_subplot(122)
ax1.boxplot(pDist_H1_05_Med.T)
ax1.set_xticklabels([1, 10, 50, 100, 500, 1000, 1500])
ax1.axhline(0.1)
ax1.set_xlabel("dimension")
ax1.set_ylabel("p value")

plt.show()

# %%
fig = plt.figure(figsize =(13, 5))
# fig.suptitle("H1, samplesize=100, bandwidth=1, mean=0.5all", fontsize = 16)

ax = fig.add_subplot(121)
ax.boxplot(pDist_H1_05_bd1.T)
ax.set_xticklabels([1, 10, 50, 100, 500, 1000, 1500])
ax.set_xlabel("dimension")
ax.set_ylabel("p value")

ax1 = fig.add_subplot(122)
ax1.boxplot(pDist_H1_05_bd1_all.T)
ax1.set_xticklabels([1, 10, 50, 100, 500, 1000, 1500])
ax1.set_xlabel("dimension")
ax1.set_ylabel("p value")

plt.show()

# %%
pDist_H0_dim_100 = np.loadtxt("pDist_H0_dim_100.csv", dtype = float, delimiter = ",")

# %%
ndMatrix = np.loadtxt("ndMatrix.csv", dtype = float, delimiter = ",")
nmMatrix = np.loadtxt("nmMatrix.csv", dtype = float, delimiter = ",")

# %%
print(ndMatrix)
# Out:
# [[6968. 6956. 7173. 7416. 7617. 7790. 8085.]
#  [6600. 6589. 6787. 7008. 7190. 7348. 7616.]
#  [6115. 6106. 6278. 6471. 6631. 6769. 7004.]
#  [5829. 5820. 5979. 6156. 6303. 6430. 6646.]
#  [5447. 5439. 5579. 5737. 5867. 5980. 6171.]
#  [5218. 5211. 5341. 5487. 5607. 5712. 5890.]
#  [4909. 4903. 5019. 5150. 5258. 5352. 5511.]
#  [4723. 4717. 4825. 4947. 5048. 5135. 5284.]]

# %%
print(nmMatrix)
# Out:
# [[4915. 5012. 5201. 5484. 5735. 5957. 6338.]
#  [4496. 4581. 4746. 5002. 5229. 5430. 5776.]
#  [3966. 4037. 4172. 4393. 4591. 4766. 5067.]
#  [3666. 3729. 3848. 4049. 4230. 4391. 4667.]
#  [3280. 3333. 3431. 3608. 3767. 3909. 4153.]
#  [3058. 3105. 3191. 3354. 3501. 3632. 3857.]
#  [2767. 2808. 2878. 3022. 3154. 3271. 3472.]
#  [2597. 2634. 2696. 2829. 2952. 3060. 3248.]]
